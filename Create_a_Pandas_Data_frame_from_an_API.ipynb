# %% [markdown]
# <a href="https://colab.research.google.com/github/MohandMouri/Data-Analysis/blob/main/Create_a_Pandas_Data_frame_from_an_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Steps:
#
#
# 1.   Import Pandas
# 2.   Import Requests
# 1.   Make a GET request from an API endpoint
# 2.   Extract Data from the Request using the Json() Method
# 1.   Explore JSON using the Keys() and Type() Method
# 2.   JSON to Dataframe

# %% [markdown]
# ####Step 1:Import pandas

# %%
import pandas as pd

# %% [markdown]
# ####Step 2: Import requests

# %%
import requests

# %% [markdown]
# ####Step 3: Make a GET Request from an API Endpoint

# %%
url = 'https://api.covid19api.com/summary'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4: Extract Data from the Request using the Json() Method

# %%
# We’ll use a method called json() to extract the json-structured data from the request.

json = response.json()
json
# Out:
# {'ID': '98af59e0-a8aa-4d82-9de5-1ea80a647544',
#  'Message': '',
#  'Global': {'NewConfirmed': 218112,
#   'TotalConfirmed': 619990042,
#   'NewDeaths': 528,
#   'TotalDeaths': 6551872,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-10T17:11:46.838Z'},
#  'Countries': [{'ID': '6a619525-beba-488d-a11f-6745183a4fbd',
#    'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 170,
#    'TotalConfirmed': 200372,
#    'NewDeaths': 2,
#    'TotalDeaths': 7806,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-10T17:11:46.838Z',
#    'Premium': {}},
#   {'ID': '13d546f0-06df-4312-bd6c-10545fab5c38',
#    'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 22,
#    'TotalConfirmed': 332494,
#    'NewDeaths': 0,
#    'TotalDeaths': 3589,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-10T17:11:46.838Z',
#    'Premium': {}},
# ...

# %% [markdown]
# #### Step 5: Exploring our JSON using the Keys() and Type() Methods

# %%
#The keys() method returns a view object. The view object contains the keys of the dictionary, as a list.
json.keys()
# Out:
# dict_keys(['ID', 'Message', 'Global', 'Countries', 'Date'])

# %%
# Explore the Values of the keys
json['Global']
# Out:
# {'NewConfirmed': 218112,
#  'TotalConfirmed': 619990042,
#  'NewDeaths': 528,
#  'TotalDeaths': 6551872,
#  'NewRecovered': 0,
#  'TotalRecovered': 0,
#  'Date': '2022-10-10T17:11:46.838Z'}

# %%
json['Countries']
# Out:
# [{'ID': '6a619525-beba-488d-a11f-6745183a4fbd',
#   'Country': 'Afghanistan',
#   'CountryCode': 'AF',
#   'Slug': 'afghanistan',
#   'NewConfirmed': 170,
#   'TotalConfirmed': 200372,
#   'NewDeaths': 2,
#   'TotalDeaths': 7806,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-10T17:11:46.838Z',
#   'Premium': {}},
#  {'ID': '13d546f0-06df-4312-bd6c-10545fab5c38',
#   'Country': 'Albania',
#   'CountryCode': 'AL',
#   'Slug': 'albania',
#   'NewConfirmed': 22,
#   'TotalConfirmed': 332494,
#   'NewDeaths': 0,
#   'TotalDeaths': 3589,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-10T17:11:46.838Z',
#   'Premium': {}},
#  {'ID': 'b2b4922a-6dd0-4c3b-86f4-250bd13659e6',
#   'Country': 'Algeria',
#   'CountryCode': 'DZ',
#   'Slug': 'algeria',
#   'NewConfirmed': 6,
#   'TotalConfirmed': 270707,
#   'NewDeaths': 0,
#   'TotalDeaths': 6881,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-10T17:11:46.838Z',
# ...

# %%
# Check the type of each keys

print(type(json['Global']))
print(type(json['Countries']))
print(type(json['Date']))
# Out:
# <class 'dict'>
# <class 'list'>
# <class 'str'>

# %% [markdown]
# ### Step 6: JSON to Dataframe

# %%
df = pd.DataFrame(json['Countries'])
df
# Out:
#                                        ID                          Country  \
# 0    6a619525-beba-488d-a11f-6745183a4fbd                      Afghanistan
# 1    13d546f0-06df-4312-bd6c-10545fab5c38                          Albania
# 2    b2b4922a-6dd0-4c3b-86f4-250bd13659e6                          Algeria
# 3    61399cfa-d685-40a4-b837-8f9235e39acf                          Andorra
# 4    edcb48a4-e30a-47c1-bc2d-d2135451e2ef                           Angola
# ..                                    ...                              ...
# 192  05fdcf7e-6e89-41c5-85d2-9edc040d2301  Venezuela (Bolivarian Republic)
# 193  091441b5-c2ee-47d9-b2ce-d6a14d1bd6a5                         Viet Nam
# 194  6ec7e9af-72ed-4128-91f8-798abf6597e5                            Yemen
# 195  9d19ec23-9e35-4051-8698-22383bf9e64c                           Zambia
# 196  006568ff-6e1e-4c0a-88fc-f068ba4a148b                         Zimbabwe
#
# ...
